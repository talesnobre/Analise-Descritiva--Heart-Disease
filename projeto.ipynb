# %%
from sklearn.model_selection import KFold,cross_val_score, RepeatedStratifiedKFold,StratifiedKFold
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import OneHotEncoder,StandardScaler,PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from sklearn.dummy import DummyClassifier

from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer

from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import accuracy_score,classification_report

import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set()

arquivo = pd.read_csv('heart.csv')

dados = pd.DataFrame(arquivo, copy=True)

doenca_cardiaca = dados.query('HeartDisease == 1')
sem_doenca_cardiaca = dados.query('HeartDisease == 0')

##### SEPARAÇÃO POR IDADES COM E SEM DOENÇA CARDÍACA

idade40_com_doenca = doenca_cardiaca.query('Age < 40')
idade40_50_com_doenca = doenca_cardiaca.query('Age >= 40 and Age < 50')
idade50_60_com_doenca = doenca_cardiaca.query('Age >= 50 and Age < 60')
idade60_70_com_doenca = doenca_cardiaca.query('Age >= 60 and Age < 70')
idade70_com_doenca = doenca_cardiaca.query('Age > 70')

idade40_sem_doenca = sem_doenca_cardiaca.query('Age < 40')
idade40_50_sem_doenca = sem_doenca_cardiaca.query('Age >= 40 and Age < 50')
idade50_60_sem_doenca = sem_doenca_cardiaca.query('Age >= 50 and Age < 60')
idade60_70_sem_doenca = sem_doenca_cardiaca.query('Age >= 60 and Age < 70')
idade70_sem_doenca = sem_doenca_cardiaca.query('Age > 70')

##### SEPARAÇÃO POR SEXOS COM E SEM DOENÇA CARDÍACA

masculino_com_doenca = doenca_cardiaca.query("Sex == 'M'")
feminino_com_doenca = doenca_cardiaca.query("Sex == 'F'")

masculino_sem_doenca = sem_doenca_cardiaca.query("Sex == 'M'")
feminino_sem_doenca = sem_doenca_cardiaca.query("Sex == 'F'")


##### SEPARAÇÃO POR _IDADES_ POR _SEXOS_ COM E SEM _DOENÇA CARDÍACA_

masculino_idade40_com_doenca = doenca_cardiaca.query("Age < 40 and Sex == 'M'")
masculino_idade40_50_com_doenca = doenca_cardiaca.query("Age >= 40 and Age < 50 and Sex == 'M'")
masculino_idade50_60_com_doenca = doenca_cardiaca.query("Age >= 50 and Age < 60 and Sex == 'M'")
masculino_idade60_70_com_doenca = doenca_cardiaca.query("Age >= 60 and Age < 70 and Sex == 'M'")
masculino_idade70_com_doenca = doenca_cardiaca.query("Age > 70 and Sex == 'M'")

masculino_idade40_sem_doenca = sem_doenca_cardiaca.query("Age < 40 and Sex == 'M'")
masculino_idade40_50_sem_doenca = sem_doenca_cardiaca.query("Age >= 40 and Age < 50 and Sex == 'M'")
masculino_idade50_60_sem_doenca = sem_doenca_cardiaca.query("Age >= 50 and Age < 60 and Sex == 'M'")
masculino_idade60_70_sem_doenca = sem_doenca_cardiaca.query("Age >= 60 and Age < 70 and Sex == 'M'")
masculino_idade70_sem_doenca = sem_doenca_cardiaca.query("Age > 70 and Sex == 'M'")

feminino_idade40_com_doenca = doenca_cardiaca.query("Age < 40 and Sex == 'F'")
feminino_idade40_50_com_doenca = doenca_cardiaca.query("Age >= 40 and Age < 50 and Sex == 'F'")
feminino_idade50_60_com_doenca = doenca_cardiaca.query("Age >= 50 and Age < 60 and Sex == 'F'")
feminino_idade60_70_com_doenca = doenca_cardiaca.query("Age >= 60 and Age < 70 and Sex == 'F'")
feminino_idade70_com_doenca = doenca_cardiaca.query("Age > 70 and Sex == 'F'")

feminino_idade40_sem_doenca = sem_doenca_cardiaca.query("Age < 40 and Sex == 'F'")
feminino_idade40_50_sem_doenca = sem_doenca_cardiaca.query("Age >= 40 and Age < 50 and Sex == 'F'")
feminino_idade50_60_sem_doenca = sem_doenca_cardiaca.query("Age >= 50 and Age < 60 and Sex == 'F'")
feminino_idade60_70_sem_doenca = sem_doenca_cardiaca.query("Age >= 60 and Age < 60  and Sex == 'F'")
feminino_idade70_sem_doenca = sem_doenca_cardiaca.query("Age > 70 and Sex == 'F'")

## SEPARAÇÃO POR TIPOS DE ANGINA COM E SEM DOENÇA CARDÍACA

angina_ATA_com_doenca = doenca_cardiaca.query("ChestPainType == 'ATA'")
angina_ASY_com_doenca = doenca_cardiaca.query("ChestPainType == 'ASY'")
angina_NAP_com_doenca = doenca_cardiaca.query("ChestPainType == 'NAP'")
angina_TA_com_doenca = doenca_cardiaca.query("ChestPainType == 'TA'")

angina_ATA_sem_doenca = sem_doenca_cardiaca.query("ChestPainType == 'ATA'")
angina_ASY_sem_doenca = sem_doenca_cardiaca.query("ChestPainType == 'ASY'")
angina_NAP_sem_doenca = sem_doenca_cardiaca.query("ChestPainType == 'NAP'")
angina_TA_sem_doenca = sem_doenca_cardiaca.query("ChestPainType == 'TA'")

## SEPARAÇÃO POR COLESTEROL COM E SEM DOENÇA CARDÍACA

colesterol_ideal_com_doenca = doenca_cardiaca.query('Cholesterol < 200')
colesterol_superior_com_doenca = doenca_cardiaca.query('Cholesterol >= 200 and Cholesterol <= 240')
colesterol_idesejavel_com_doenca = doenca_cardiaca.query('Cholesterol > 240')

colesterol_ideal_sem_doenca = sem_doenca_cardiaca.query('Cholesterol < 200')
colesterol_superior_sem_doenca = sem_doenca_cardiaca.query('Cholesterol >= 200 and Cholesterol <= 240')
colesterol_idesejavel_sem_doenca = sem_doenca_cardiaca.query('Cholesterol > 240')

###### SEPARAÇÃO POR COLESTEROL COM E SEM DOENÇA CARDÍACA E POR SEXOS ######

## MASCULINO
masc_colesterol_ideal_com_doenca = doenca_cardiaca.query("Cholesterol < 200 and Sex == 'M'")
masc_colesterol_superior_com_doenca = doenca_cardiaca.query("Cholesterol >= 200 and Cholesterol <= 240 and Sex == 'M'")
masc_colesterol_idesejavel_com_doenca = doenca_cardiaca.query("Cholesterol > 240 and Sex == 'M'")

masc_colesterol_ideal_sem_doenca = sem_doenca_cardiaca.query("Cholesterol < 200 and Sex == 'M'")
masc_colesterol_superior_sem_doenca = sem_doenca_cardiaca.query("Cholesterol >= 200 and Cholesterol <= 240 and Sex == 'M'")
masc_colesterol_idesejavel_sem_doenca = sem_doenca_cardiaca.query("Cholesterol > 240 and Sex == 'M'")

## FEMININO
fem_colesterol_ideal_com_doenca = doenca_cardiaca.query("Cholesterol < 200 and Sex == 'F'")
fem_colesterol_superior_com_doenca = doenca_cardiaca.query("Cholesterol >= 200 and Cholesterol <= 240 and Sex == 'F'")
fem_colesterol_idesejavel_com_doenca = doenca_cardiaca.query("Cholesterol > 240 and Sex == 'F'")

fem_colesterol_ideal_sem_doenca = sem_doenca_cardiaca.query("Cholesterol < 200 and Sex == 'F'")
fem_colesterol_superior_sem_doenca = sem_doenca_cardiaca.query("Cholesterol >= 200 and Cholesterol <= 240 and Sex == 'F'")
fem_colesterol_idesejavel_sem_doenca = sem_doenca_cardiaca.query("Cholesterol > 240 and Sex == 'F'")


###### SEPARAÇÃO POR _INTERVALO ST_ COM E SEM _DOENÇA CARDÍACA_ E POR _SEXOS_ ######

## Vale lembrar que quem tem o intervalo ST em _UP_ deveria ter menor indice de doença cardiaca
## e que quem tem o intervalo ST em _DOWN_ deveria ter maior indice de doença cardiaca

## MASCULINO
masculino_com_doenca_intervalo_ST_Up = doenca_cardiaca.query("ST_Slope == 'Up' and Sex == 'M'")
masculino_com_doenca_intervalo_ST_Flat = doenca_cardiaca.query("ST_Slope == 'Flat' and Sex == 'M'")
masculino_com_doenca_intervalo_ST_Down = doenca_cardiaca.query("ST_Slope == 'Down' and Sex == 'M'")

masculino_sem_doenca_intervalo_ST_Up = sem_doenca_cardiaca.query("ST_Slope == 'Up' and Sex == 'M'")
masculino_sem_doenca_intervalo_ST_Flat = sem_doenca_cardiaca.query("ST_Slope == 'Flat' and Sex == 'M'")
masculino_sem_doenca_intervalo_ST_Down = sem_doenca_cardiaca.query("ST_Slope == 'Down' and Sex == 'M'")

## FEMININO
feminino_com_doenca_intervalo_ST_Up = doenca_cardiaca.query("ST_Slope == 'Up' and Sex == 'F'")
feminino_com_doenca_intervalo_ST_Flat = doenca_cardiaca.query("ST_Slope == 'Flat' and Sex == 'F'")
feminino_com_doenca_intervalo_ST_Down = doenca_cardiaca.query("ST_Slope == 'Down' and Sex == 'F'")

feminino_sem_doenca_intervalo_ST_Up = sem_doenca_cardiaca.query("ST_Slope == 'Up' and Sex == 'F'")
feminino_sem_doenca_intervalo_ST_Flat = sem_doenca_cardiaca.query("ST_Slope == 'Flat' and Sex == 'F'")
feminino_sem_doenca_intervalo_ST_Down = sem_doenca_cardiaca.query("ST_Slope == 'Down' and Sex == 'F'")

# %%
categorical = dados.select_dtypes('object').columns
numerical = dados.drop(['HeartDisease'], axis=1).select_dtypes('number').columns
dados[numerical].describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak
# count  918.000000  918.000000   918.000000  918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368    0.887364
# std      9.432617   18.514154   109.384145    0.423046   25.460334    1.066570
# min     28.000000    0.000000     0.000000    0.000000   60.000000   -2.600000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000    0.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000    0.600000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000    1.500000
# max     77.000000  200.000000   603.000000    1.000000  202.000000    6.200000
